# %%
import torch
print(torch.__version__)
print(torch.cuda.is_available())
# Out:
# The kernel failed to start as the Python Environment 'ai-engineering-from-scratch (3.12.3) (Python 3.12.3)' is no longer available. Consider selecting another kernel or refreshing the list of Python Environments.
